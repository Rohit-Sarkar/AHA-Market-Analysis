# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('D:/UTD_JSOM/Spring 2018/Practicum/Market Analysis/donations/hag_county_2015-full.csv')

# %%
data.head()
# Out:
#    statefips  countyfips     county_name state_postal  cbsa_code  cy_pop_2015  \
# 0          1           1  Autauga County           AL    33860.0        55221
# 1          1           3  Baldwin County           AL    19300.0       195121
# 2          1           5  Barbour County           AL        NaN        26932
# 3          1           7     Bibb County           AL    13820.0        22604
# 4          1           9   Blount County           AL    13820.0        57710
#
#    cy_gratio  cy_bracket_gratio_5  cy_bracket_gratio_6  cy_bracket_gratio_7  \
# 0     0.0464               0.0615               0.0536               0.0461
# 1     0.0367               0.0506               0.0440               0.0370
# 2     0.0547               0.0713               0.0636               0.0506
# 3     0.0505               0.0646               0.0492               0.0525
# 4     0.0463               0.0553               0.0485               0.0440
#
#              ...             itemized_agi_8  cy_amt_contributions  \
# 0            ...                     119887                 26156
# 1            ...                    1363393                111536
# 2            ...                      37404                  7520
# 3            ...                      48382                  7180
# 4            ...                     101447                 18967
#
#    amt_contributions_5  amt_contributions_6  amt_contributions_7  \
# 0                 4263                 4932                13020
# 1                13548                14483                39767
# 2                 1439                 1380                 2951
# 3                 1456                  979                 2693
# 4                 3217                 3942                 7413
#
#    amt_contributions_8  avg_giving_by_itemizer_5  avg_giving_by_itemizer_6  \
# 0                 3941                    3.8405                    4.6528
# 1                43738                    3.1361                    3.8315
# 2                 1750                    4.3606                    5.5200
# 3                 2052                    4.0444                    4.2565
# 4                 4395                    3.4591                    4.2387
#
#    avg_giving_by_itemizer_7  avg_giving_by_itemizer_8
# 0                    6.2297                   10.9472
# 1                    5.0853                   13.6255
# 2                    6.8628                   19.4444
# 3                    6.9051                   29.3143
# 4                    5.7914                   16.9038
#
# [5 rows x 36 columns]

# %%
data.columns
# Out:
# Index(['statefips', 'countyfips', 'county_name', 'state_postal', 'cbsa_code',
#        'cy_pop_2015', 'cy_gratio', 'cy_bracket_gratio_5',
#        'cy_bracket_gratio_6', 'cy_bracket_gratio_7', 'cy_bracket_gratio_8',
#        'cy_avg_giving_by_itemizer', 'gvsa', 'gvsa_5', 'gvsa_6', 'gvsa_7',
#        'gvsa_8', 'god', 'god_5', 'god_6', 'god_7', 'god_8', 'cy_itemized_agi',
#        'itemized_agi_5', 'itemized_agi_6', 'itemized_agi_7', 'itemized_agi_8',
#        'cy_amt_contributions', 'amt_contributions_5', 'amt_contributions_6',
#        'amt_contributions_7', 'amt_contributions_8',
#        'avg_giving_by_itemizer_5', 'avg_giving_by_itemizer_6',
#        'avg_giving_by_itemizer_7', 'avg_giving_by_itemizer_8'],
#       dtype='object')

# %%
data.corr()
# Out:
#                            statefips  countyfips  cbsa_code  cy_pop_2015  \
# statefips                   1.000000    0.193259   0.080714    -0.078565
# countyfips                  0.193259    1.000000   0.087147    -0.057999
# cbsa_code                   0.080714    0.087147   1.000000     0.026293
# cy_pop_2015                -0.078565   -0.057999   0.026293     1.000000
# cy_gratio                  -0.075079    0.151880  -0.036186    -0.112286
# cy_bracket_gratio_5        -0.109552    0.124057  -0.021653    -0.107224
# cy_bracket_gratio_6        -0.076061    0.131902  -0.021518    -0.146094
# cy_bracket_gratio_7        -0.041052    0.140019  -0.020631    -0.163385
# cy_bracket_gratio_8        -0.050926    0.129515  -0.046347    -0.050253
# cy_avg_giving_by_itemizer  -0.024969    0.087937  -0.012757     0.064888
# gvsa                        0.080571    0.180017   0.027210    -0.057726
# gvsa_5                     -0.004684    0.074551   0.040588    -0.039153
# gvsa_6                      0.012462    0.104964   0.034995    -0.083709
# gvsa_7                      0.011456    0.137462   0.030041    -0.110776
# gvsa_8                      0.106787    0.148762   0.010768    -0.006788
# god                        -0.065527   -0.042574   0.033404     0.545356
# god_5                      -0.011414   -0.031238  -0.016007     0.327467
# god_6                      -0.022786   -0.029491   0.005754     0.343670
# god_7                      -0.033346   -0.025151   0.016255     0.371675
# god_8                      -0.065899   -0.039619   0.035449     0.503364
# cy_itemized_agi            -0.075402   -0.063598   0.030931     0.887045
# itemized_agi_5             -0.076603   -0.068187   0.027959     0.983530
# itemized_agi_6             -0.077042   -0.074846   0.034024     0.969786
# itemized_agi_7             -0.078730   -0.075592   0.036474     0.937568
# itemized_agi_8             -0.069538   -0.053823   0.027013     0.799416
# cy_amt_contributions       -0.069435   -0.046341   0.023726     0.826304
# amt_contributions_5        -0.073407   -0.047536   0.022125     0.962623
# amt_contributions_6        -0.070789   -0.057079   0.027790     0.962047
# amt_contributions_7        -0.070212   -0.057266   0.029229     0.950763
# amt_contributions_8        -0.061961   -0.038103   0.019855     0.691072
# avg_giving_by_itemizer_5   -0.106978    0.123543  -0.021708    -0.106483
# avg_giving_by_itemizer_6   -0.075113    0.129860  -0.021677    -0.146453
# avg_giving_by_itemizer_7   -0.035224    0.142643  -0.028132    -0.151621
# avg_giving_by_itemizer_8   -0.048601    0.078768  -0.034658     0.056921
#
#                            cy_gratio  cy_bracket_gratio_5  \
# statefips                  -0.075079            -0.109552
# countyfips                  0.151880             0.124057
# cbsa_code                  -0.036186            -0.021653
# cy_pop_2015                -0.112286            -0.107224
# cy_gratio                   1.000000             0.865212
# cy_bracket_gratio_5         0.865212             1.000000
# cy_bracket_gratio_6         0.885524             0.936096
# cy_bracket_gratio_7         0.907713             0.894982
# cy_bracket_gratio_8         0.821942             0.530942
# cy_avg_giving_by_itemizer   0.650078             0.459429
# gvsa                        0.686324             0.525336
# gvsa_5                      0.535979             0.674310
# gvsa_6                      0.519332             0.539790
# gvsa_7                      0.580160             0.552941
# gvsa_8                      0.527909             0.249375
# god                        -0.173847            -0.133901
# god_5                      -0.159481            -0.178053
# god_6                      -0.136042            -0.160501
# god_7                      -0.112307            -0.127671
# god_8                      -0.156709            -0.104530
# cy_itemized_agi            -0.118630            -0.131265
# itemized_agi_5             -0.136218            -0.127495
# itemized_agi_6             -0.150663            -0.144505
# itemized_agi_7             -0.167661            -0.160335
# itemized_agi_8             -0.088474            -0.111786
# cy_amt_contributions       -0.039381            -0.077953
# amt_contributions_5        -0.048870            -0.034350
# amt_contributions_6        -0.064478            -0.055659
# amt_contributions_7        -0.093002            -0.085906
# amt_contributions_8        -0.019553            -0.074270
# avg_giving_by_itemizer_5    0.865081             0.998735
# avg_giving_by_itemizer_6    0.883742             0.935189
# avg_giving_by_itemizer_7    0.895988             0.881708
# avg_giving_by_itemizer_8    0.671151             0.364953
#
#                            cy_bracket_gratio_6  cy_bracket_gratio_7  \
# statefips                            -0.076061            -0.041052
# countyfips                            0.131902             0.140019
# cbsa_code                            -0.021518            -0.020631
# cy_pop_2015                          -0.146094            -0.163385
# cy_gratio                             0.885524             0.907713
# cy_bracket_gratio_5                   0.936096             0.894982
# cy_bracket_gratio_6                   1.000000             0.927158
# cy_bracket_gratio_7                   0.927158             1.000000
# cy_bracket_gratio_8                   0.546311             0.581581
# cy_avg_giving_by_itemizer             0.456474             0.469235
# gvsa                                  0.539154             0.569799
# gvsa_5                                0.579779             0.552197
# gvsa_6                                0.644297             0.541626
# gvsa_7                                0.578433             0.676131
# gvsa_8                                0.266414             0.294669
# god                                  -0.170096            -0.188037
# god_5                                -0.196816            -0.196491
# god_6                                -0.200135            -0.201735
# god_7                                -0.168872            -0.187232
# god_8                                -0.133305            -0.149865
# cy_itemized_agi                      -0.178436            -0.196005
# itemized_agi_5                       -0.171647            -0.188401
# itemized_agi_6                       -0.190554            -0.206019
# itemized_agi_7                       -0.208376            -0.226877
# itemized_agi_8                       -0.156316            -0.172836
# cy_amt_contributions                 -0.122433            -0.138395
# amt_contributions_5                  -0.078163            -0.099573
# amt_contributions_6                  -0.095634            -0.113951
# amt_contributions_7                  -0.127071            -0.144045
# amt_contributions_8                  -0.115643            -0.129103
# avg_giving_by_itemizer_5              0.935174             0.895594
# avg_giving_by_itemizer_6              0.998540             0.924423
# avg_giving_by_itemizer_7              0.917591             0.984563
# avg_giving_by_itemizer_8              0.367866             0.398248
#
#                            cy_bracket_gratio_8  cy_avg_giving_by_itemizer  \
# statefips                            -0.050926                  -0.024969
# countyfips                            0.129515                   0.087937
# cbsa_code                            -0.046347                  -0.012757
# cy_pop_2015                          -0.050253                   0.064888
# cy_gratio                             0.821942                   0.650078
# cy_bracket_gratio_5                   0.530942                   0.459429
# cy_bracket_gratio_6                   0.546311                   0.456474
# cy_bracket_gratio_7                   0.581581                   0.469235
# cy_bracket_gratio_8                   1.000000                   0.575943
# cy_avg_giving_by_itemizer             0.575943                   1.000000
# gvsa                                  0.617051                   0.474601
# gvsa_5                                0.303262                   0.282164
# gvsa_6                                0.295648                   0.244713
# gvsa_7                                0.351751                   0.273143
# gvsa_8                                0.783941                   0.388103
# god                                  -0.127962                   0.011754
# god_5                                -0.081853                  -0.001432
# god_6                                -0.064009                   0.073981
# god_7                                -0.051128                   0.098911
# god_8                                -0.126845                  -0.013220
# cy_itemized_agi                      -0.051910                   0.137990
# itemized_agi_5                       -0.067439                   0.042265
# itemized_agi_6                       -0.076997                   0.042311
# itemized_agi_7                       -0.090244                   0.053543
# itemized_agi_8                       -0.030534                   0.180584
# cy_amt_contributions                  0.018242                   0.217635
# amt_contributions_5                  -0.004385                   0.093330
# amt_contributions_6                  -0.013168                   0.088763
# amt_contributions_7                  -0.033077                   0.093527
# amt_contributions_8                   0.033578                   0.248676
# avg_giving_by_itemizer_5              0.531691                   0.461440
# avg_giving_by_itemizer_6              0.548457                   0.456611
# avg_giving_by_itemizer_7              0.582603                   0.479687
# avg_giving_by_itemizer_8              0.806573                   0.873333
#
#                                      ...             itemized_agi_8  \
# statefips                            ...                  -0.069538
# countyfips                           ...                  -0.053823
# cbsa_code                            ...                   0.027013
# cy_pop_2015                          ...                   0.799416
# cy_gratio                            ...                  -0.088474
# cy_bracket_gratio_5                  ...                  -0.111786
# cy_bracket_gratio_6                  ...                  -0.156316
# cy_bracket_gratio_7                  ...                  -0.172836
# cy_bracket_gratio_8                  ...                  -0.030534
# cy_avg_giving_by_itemizer            ...                   0.180584
# gvsa                                 ...                  -0.021628
# gvsa_5                               ...                  -0.045204
# gvsa_6                               ...                  -0.099814
# gvsa_7                               ...                  -0.125583
# gvsa_8                               ...                   0.013606
# god                                  ...                   0.582429
# god_5                                ...                   0.300742
# god_6                                ...                   0.509048
# god_7                                ...                   0.538690
# god_8                                ...                   0.499451
# cy_itemized_agi                      ...                   0.980822
# itemized_agi_5                       ...                   0.794750
# itemized_agi_6                       ...                   0.828529
# itemized_agi_7                       ...                   0.867487
# itemized_agi_8                       ...                   1.000000
# cy_amt_contributions                 ...                   0.975759
# amt_contributions_5                  ...                   0.748516
# amt_contributions_6                  ...                   0.766255
# amt_contributions_7                  ...                   0.812079
# amt_contributions_8                  ...                   0.958304
# avg_giving_by_itemizer_5             ...                  -0.110308
# avg_giving_by_itemizer_6             ...                  -0.156385
# avg_giving_by_itemizer_7             ...                  -0.158364
# avg_giving_by_itemizer_8             ...                   0.124417
#
#                            cy_amt_contributions  amt_contributions_5  \
# statefips                             -0.069435            -0.073407
# countyfips                            -0.046341            -0.047536
# cbsa_code                              0.023726             0.022125
# cy_pop_2015                            0.826304             0.962623
# cy_gratio                             -0.039381            -0.048870
# cy_bracket_gratio_5                   -0.077953            -0.034350
# cy_bracket_gratio_6                   -0.122433            -0.078163
# cy_bracket_gratio_7                   -0.138395            -0.099573
# cy_bracket_gratio_8                    0.018242            -0.004385
# cy_avg_giving_by_itemizer              0.217635             0.093330
# gvsa                                   0.007709            -0.029494
# gvsa_5                                -0.036170            -0.006693
# gvsa_6                                -0.092947            -0.054813
# gvsa_7                                -0.116633            -0.081847
# gvsa_8                                 0.044108             0.011310
# god                                    0.513997             0.522100
# god_5                                  0.323179             0.323500
# god_6                                  0.530962             0.330859
# god_7                                  0.556958             0.354812
# god_8                                  0.413786             0.481404
# cy_itemized_agi                        0.966781             0.843498
# itemized_agi_5                         0.818347             0.972605
# itemized_agi_6                         0.843902             0.951096
# itemized_agi_7                         0.865225             0.905278
# itemized_agi_8                         0.975759             0.748516
# cy_amt_contributions                   1.000000             0.801330
# amt_contributions_5                    0.801330             1.000000
# amt_contributions_6                    0.814355             0.990951
# amt_contributions_7                    0.844414             0.958362
# amt_contributions_8                    0.973545             0.650357
# avg_giving_by_itemizer_5              -0.076347            -0.033327
# avg_giving_by_itemizer_6              -0.122398            -0.078409
# avg_giving_by_itemizer_7              -0.124627            -0.088856
# avg_giving_by_itemizer_8               0.169908             0.083878
#
#                            amt_contributions_6  amt_contributions_7  \
# statefips                            -0.070789            -0.070212
# countyfips                           -0.057079            -0.057266
# cbsa_code                             0.027790             0.029229
# cy_pop_2015                           0.962047             0.950763
# cy_gratio                            -0.064478            -0.093002
# cy_bracket_gratio_5                  -0.055659            -0.085906
# cy_bracket_gratio_6                  -0.095634            -0.127071
# cy_bracket_gratio_7                  -0.113951            -0.144045
# cy_bracket_gratio_8                  -0.013168            -0.033077
# cy_avg_giving_by_itemizer             0.088763             0.093527
# gvsa                                 -0.041457            -0.062677
# gvsa_5                               -0.022503            -0.046491
# gvsa_6                               -0.067416            -0.093712
# gvsa_7                               -0.094347            -0.119657
# gvsa_8                                0.006085            -0.006645
# god                                   0.551700             0.601600
# god_5                                 0.354200             0.392414
# god_6                                 0.363767             0.417873
# god_7                                 0.383575             0.447868
# god_8                                 0.505083             0.542438
# cy_itemized_agi                       0.864209             0.901789
# itemized_agi_5                        0.977240             0.963047
# itemized_agi_6                        0.968497             0.969322
# itemized_agi_7                        0.935651             0.968683
# itemized_agi_8                        0.766255             0.812079
# cy_amt_contributions                  0.814355             0.844414
# amt_contributions_5                   0.990951             0.958362
# amt_contributions_6                   1.000000             0.983223
# amt_contributions_7                   0.983223             1.000000
# amt_contributions_8                   0.661581             0.701647
# avg_giving_by_itemizer_5             -0.053909            -0.083795
# avg_giving_by_itemizer_6             -0.095524            -0.126665
# avg_giving_by_itemizer_7             -0.102326            -0.128928
# avg_giving_by_itemizer_8              0.075840             0.065551
#
#                            amt_contributions_8  avg_giving_by_itemizer_5  \
# statefips                            -0.061961                 -0.106978
# countyfips                           -0.038103                  0.123543
# cbsa_code                             0.019855                 -0.021708
# cy_pop_2015                           0.691072                 -0.106483
# cy_gratio                            -0.019553                  0.865081
# cy_bracket_gratio_5                  -0.074270                  0.998735
# cy_bracket_gratio_6                  -0.115643                  0.935174
# cy_bracket_gratio_7                  -0.129103                  0.895594
# cy_bracket_gratio_8                   0.033578                  0.531691
# cy_avg_giving_by_itemizer             0.248676                  0.461440
# gvsa                                  0.031562                  0.525216
# gvsa_5                               -0.033989                  0.673067
# gvsa_6                               -0.089321                  0.537441
# gvsa_7                               -0.109555                  0.552430
# gvsa_8                                0.058265                  0.250576
# god                                   0.438440                 -0.132411
# god_5                                 0.272043                 -0.177106
# god_6                                 0.538794                 -0.158912
# god_7                                 0.562018                 -0.126048
# god_8                                 0.328111                 -0.103336
# cy_itemized_agi                       0.907689                 -0.129615
# itemized_agi_5                        0.675367                 -0.126365
# itemized_agi_6                        0.710301                 -0.142848
# itemized_agi_7                        0.745629                 -0.158359
# itemized_agi_8                        0.958304                 -0.110308
# cy_amt_contributions                  0.973545                 -0.076347
# amt_contributions_5                   0.650357                 -0.033327
# amt_contributions_6                   0.661581                 -0.053909
# amt_contributions_7                   0.701647                 -0.083795
# amt_contributions_8                   1.000000                 -0.072904
# avg_giving_by_itemizer_5             -0.072904                  1.000000
# avg_giving_by_itemizer_6             -0.115682                  0.934398
# avg_giving_by_itemizer_7             -0.116546                  0.882006
# avg_giving_by_itemizer_8              0.194318                  0.365312
#
#                            avg_giving_by_itemizer_6  avg_giving_by_itemizer_7  \
# statefips                                 -0.075113                 -0.035224
# countyfips                                 0.129860                  0.142643
# cbsa_code                                 -0.021677                 -0.028132
# cy_pop_2015                               -0.146453                 -0.151621
# cy_gratio                                  0.883742                  0.895988
# cy_bracket_gratio_5                        0.935189                  0.881708
# cy_bracket_gratio_6                        0.998540                  0.917591
# cy_bracket_gratio_7                        0.924423                  0.984563
# cy_bracket_gratio_8                        0.548457                  0.582603
# cy_avg_giving_by_itemizer                  0.456611                  0.479687
# gvsa                                       0.537645                  0.561763
# gvsa_5                                     0.579421                  0.539270
# gvsa_6                                     0.643112                  0.532492
# gvsa_7                                     0.574794                  0.663839
# gvsa_8                                     0.269047                  0.297133
# god                                       -0.169769                 -0.174242
# god_5                                     -0.196540                 -0.185474
# god_6                                     -0.199693                 -0.189634
# god_7                                     -0.168204                 -0.172934
# god_8                                     -0.133122                 -0.138603
# cy_itemized_agi                           -0.178463                 -0.180871
# itemized_agi_5                            -0.171981                 -0.176305
# itemized_agi_6                            -0.190643                 -0.193080
# itemized_agi_7                            -0.208193                 -0.210911
# itemized_agi_8                            -0.156385                 -0.158364
# cy_amt_contributions                      -0.122398                 -0.124627
# amt_contributions_5                       -0.078409                 -0.088856
# amt_contributions_6                       -0.095524                 -0.102326
# amt_contributions_7                       -0.126665                 -0.128928
# amt_contributions_8                       -0.115682                 -0.116546
# avg_giving_by_itemizer_5                   0.934398                  0.882006
# avg_giving_by_itemizer_6                   1.000000                  0.913935
# avg_giving_by_itemizer_7                   0.913935                  1.000000
# avg_giving_by_itemizer_8                   0.369043                  0.408106
#
#                            avg_giving_by_itemizer_8
# statefips                                 -0.048601
# countyfips                                 0.078768
# cbsa_code                                 -0.034658
# cy_pop_2015                                0.056921
# cy_gratio                                  0.671151
# cy_bracket_gratio_5                        0.364953
# cy_bracket_gratio_6                        0.367866
# cy_bracket_gratio_7                        0.398248
# cy_bracket_gratio_8                        0.806573
# cy_avg_giving_by_itemizer                  0.873333
# gvsa                                       0.519871
# gvsa_5                                     0.211981
# gvsa_6                                     0.190725
# gvsa_7                                     0.234012
# gvsa_8                                     0.619485
# god                                       -0.035761
# god_5                                     -0.006512
# god_6                                      0.037936
# god_7                                      0.043943
# god_8                                     -0.053070
# cy_itemized_agi                            0.092050
# itemized_agi_5                             0.035860
# itemized_agi_6                             0.028918
# itemized_agi_7                             0.022917
# itemized_agi_8                             0.124417
# cy_amt_contributions                       0.169908
# amt_contributions_5                        0.083878
# amt_contributions_6                        0.075840
# amt_contributions_7                        0.065551
# amt_contributions_8                        0.194318
# avg_giving_by_itemizer_5                   0.365312
# avg_giving_by_itemizer_6                   0.369043
# avg_giving_by_itemizer_7                   0.408106
# avg_giving_by_itemizer_8                   1.000000
#
# [34 rows x 34 columns]

# %%
data = data[np.isfinite(data['cbsa_code'])]

# %% [markdown]
# # Clustering with Population,Giving Ratio, Giving Opportunity Dollars

# %%
data_x = data.iloc[:,[4,5,6,17]]

# %%
X = data_x.set_index('cbsa_code')

# %%
X.isnull().values.sum()

# %%
X = X[np.isfinite(X['cy_gratio'])]

# %% [markdown]
# # Without Scaling

# %%
from sklearn.metrics import silhouette_score

range_clusters = [2,3,4,5,6,7,8]

for n_clusters in range_clusters:
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.918417120399
# For n_clusters = 3 The average silhouette_score is : 0.859332805918
# For n_clusters = 4 The average silhouette_score is : 0.829182547532
# For n_clusters = 5 The average silhouette_score is : 0.811781958816
# For n_clusters = 6 The average silhouette_score is : 0.737586220223
# For n_clusters = 7 The average silhouette_score is : 0.727525829505
# For n_clusters = 8 The average silhouette_score is : 0.678973827692

# %% [markdown]
# range_clust = range(1,9)
#
# for n_cluster in range_clust:
#     clust = KMeans(n_clusters=n_cluster, random_state = 9, n_jobs=-1)
#     clust.fit(X)
#     label = clust.labels_
#     series = pd.Series(label)
#     print('Count of different labels in',n_cluster,'cluster')
#     print(series.value_counts())
#
# #cluster4 = KMeans(n_clusters=3, random_state= 99, n_jobs=-1).fit(X)

# %% [markdown]
# # With Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

range_clust = range(1,9)

for n_cluster in range_clust:
    clust = KMeans(n_clusters=n_cluster, random_state = 9, n_jobs=-1)
    clust.fit(X_scaled)
    label = clust.labels_
    series = pd.Series(label)
    print('Count of different labels in',n_cluster,'cluster')
    print(series.value_counts())
# Out:
# Count of different labels in 1 cluster
# 0    1804
# dtype: int64
# Count of different labels in 2 cluster
# 0    1696
# 1     108
# dtype: int64
# Count of different labels in 3 cluster
# 1    1052
# 0     644
# 2     108
# dtype: int64
# Count of different labels in 4 cluster
# 2    1052
# 0     644
# 3      99
# 1       9
# dtype: int64
# Count of different labels in 5 cluster
# 0    1052
# 4     644
# 2      98
# 1       9
# 3       1
# dtype: int64
# Count of different labels in 6 cluster
# 3    791
# 1    639
# 4    266
# 2     98
# 0      9
# 5      1
# dtype: int64
# Count of different labels in 7 cluster
# 2    784
# 0    642
# 3    270
# 1     83
# 6     15
# 5      9
# 4      1
# dtype: int64
# Count of different labels in 8 cluster
# 3    784
# 0    642
# 5    270
# 2     61
# 1     35
# 7      7
# 6      4
# 4      1
# dtype: int64

# %%
range_clusters = [2,3,4,5,6,7,8]

for n_clusters in range_clusters:
    clusterer = KMeans(n_clusters=n_clusters, random_state=1)
    cluster_labels = clusterer.fit_predict(X_scaled)
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.865534436366
# For n_clusters = 3 The average silhouette_score is : -0.0208957771108
# For n_clusters = 4 The average silhouette_score is : -0.0182196289777
# For n_clusters = 5 The average silhouette_score is : -0.0226882040224
# For n_clusters = 6 The average silhouette_score is : -0.153906471306
# For n_clusters = 7 The average silhouette_score is : -0.146057564841
# For n_clusters = 8 The average silhouette_score is : -0.160847550952

# %% [markdown]
# # Clustering with Giving Ratio

# %%
data_x1 = data.iloc[:,[4,6]]

X = data_x1.set_index('cbsa_code')

X.isnull().values.sum()

X = X[np.isfinite(X['cy_gratio'])]

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

range_clusters = [2,3,4,5,6,7,8]

for n_clusters in range_clusters:
    clusterer = KMeans(n_clusters=n_clusters, random_state=4)
    cluster_labels = clusterer.fit_predict(X_scaled)
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.594363720525
# For n_clusters = 3 The average silhouette_score is : 0.552671052673
# For n_clusters = 4 The average silhouette_score is : 0.535983712094
# For n_clusters = 5 The average silhouette_score is : 0.521773327873
# For n_clusters = 6 The average silhouette_score is : 0.525674351614
# For n_clusters = 7 The average silhouette_score is : 0.527008476817
# For n_clusters = 8 The average silhouette_score is : 0.535704855755

# %%
range_clust = range(1,9)

for n_cluster in range_clust:
    clust = KMeans(n_clusters=n_cluster, random_state = 9, n_jobs=-1)
    clust.fit(X_scaled)
    label = clust.labels_
    series = pd.Series(label)
    print('Count of different labels in',n_cluster,'cluster')
    print(series.value_counts())
# Out:
# Count of different labels in 1 cluster
# 0    3132
# dtype: int64
# Count of different labels in 2 cluster
# 1    2034
# 0    1098
# dtype: int64
# Count of different labels in 3 cluster
# 0    1462
# 2    1230
# 1     440
# dtype: int64
# Count of different labels in 4 cluster
# 0    1143
# 3    1087
# 2     757
# 1     145
# dtype: int64
# Count of different labels in 5 cluster
# 0    1018
# 4     818
# 3     742
# 2     490
# 1      64
# dtype: int64
# Count of different labels in 6 cluster
# 5    889
# 4    749
# 0    569
# 1    547
# 2    322
# 3     56
# dtype: int64
# Count of different labels in 7 cluster
# 0    894
# 4    729
# 2    592
# 3    497
# 6    348
# 1     69
# 5      3
# dtype: int64
# Count of different labels in 8 cluster
# 1    810
# 3    724
# 5    640
# 0    556
# 4    318
# 2     61
# 7     20
# 6      3
# dtype: int64

# %%
data_x1 = data.iloc[:,[4,6]]
X = data_x1.set_index('cbsa_code')
X.isnull().values.sum()
X = X[np.isfinite(X['cy_gratio'])]

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


clust = KMeans(n_clusters=6, random_state = 0, n_jobs=-1)
clust.fit_predict(X_scaled)
label = clust.labels_
series = pd.Series(label)

# %%
X = X.reset_index()

X_clustered = pd.concat([X,series],axis=1)

# %%
X_clustered.rename(columns={0:'cluster_label'},inplace=True)

# %%
data = data[np.isfinite(data['cbsa_code'])]

# %%
data['cbsa_code'] = data['cbsa_code'].astype('str')
data['cy_gratio'] = data['cy_gratio'].astype('str')
data['key'] = data['cbsa_code'].map(str) + data['cy_gratio']

# %%
X_clustered['cbsa_code'] = X_clustered['cbsa_code'].astype('str')
X_clustered['cy_gratio'] = X_clustered['cy_gratio'].astype('str')
X_clustered['key'] = X_clustered['cbsa_code'].map(str) + X_clustered['cy_gratio']

# %%
data = data.set_index('key')
X_clustered = X_clustered.set_index('key')
data_cl = data.join(X_clustered,lsuffix='_d',rsuffix='_c')

# %%
data_cl.columns
# Out:
# Index(['statefips', 'countyfips', 'county_name', 'state_postal', 'cbsa_code_d',
#        'cy_pop_2015', 'cy_gratio_d', 'cy_bracket_gratio_5',
#        'cy_bracket_gratio_6', 'cy_bracket_gratio_7', 'cy_bracket_gratio_8',
#        'cy_avg_giving_by_itemizer', 'gvsa', 'gvsa_5', 'gvsa_6', 'gvsa_7',
#        'gvsa_8', 'god', 'god_5', 'god_6', 'god_7', 'god_8', 'cy_itemized_agi',
#        'itemized_agi_5', 'itemized_agi_6', 'itemized_agi_7', 'itemized_agi_8',
#        'cy_amt_contributions', 'amt_contributions_5', 'amt_contributions_6',
#        'amt_contributions_7', 'amt_contributions_8',
#        'avg_giving_by_itemizer_5', 'avg_giving_by_itemizer_6',
#        'avg_giving_by_itemizer_7', 'avg_giving_by_itemizer_8', 'key_d',
#        'cbsa_code_c', 'cy_gratio_c', 'cluster_label', 'key_c'],
#       dtype='object')

# %%
data_cl['cy_gratio_d'] = data_cl['cy_gratio_d'].astype('float64')
data_cl.pivot_table(['cy_pop_2015', 'cy_gratio_d',
       'cy_avg_giving_by_itemizer', 'gvsa', 'god', 'cy_itemized_agi',
       'cy_amt_contributions'],['cluster_label'], aggfunc='mean')
# Out:
#                cy_amt_contributions  cy_avg_giving_by_itemizer  cy_gratio_d  \
# cluster_label
# 0.0                   118862.814815                   3.327207     0.022544
# 1.0                    84888.262181                   5.558217     0.038369
# 2.0                   108601.514107                   6.810612     0.047376
# 3.0                   154545.450000                  14.905795     0.081595
# 4.0                   133594.246575                   4.477411     0.030113
# 5.0                    49852.145695                   7.861941     0.058172
#
#                cy_itemized_agi    cy_pop_2015           god      gvsa
# cluster_label
# 0.0               5.249868e+06  202744.953704  22256.458009 -0.187408
# 1.0               2.215644e+06  135058.171694   3056.139758  0.101485
# 2.0               2.355807e+06  107454.181818   2896.901882  0.149847
# 3.0               1.804682e+06   96079.200000    919.384525  0.621571
# 4.0               4.485309e+06  225235.526419  10203.132942 -0.021113
# 5.0               8.701210e+05   73233.112583   1900.781261  0.306822

# %%
data_cl.to_csv('D:/UTD_JSOM/Spring 2018/Practicum/Market Analysis/cluster.csv')
